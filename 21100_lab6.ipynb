# %% [markdown]
# **AIE21100**

# %% [markdown]
# **A1. Take a portion of your recorded signal which represents a vowel sound. Perform FFT on the signal snippet and observe the amplitude spectrum. Repeat the same for a few vowelsounds.**

# %%
import librosa
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# For Vowel sound 1

# %%
vowel_a="vowel_a.m4a"
ipd.Audio(vowel_a)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mp4;base64,..." type="audio/mp4" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
time_series_vowel_a, sample_rate_vowel_a = librosa.load()
librosa.display.waveshow(time_series_vowel_a)
# Out:
# <ipython-input-29-8217713aea29>:1: UserWarning: PySoundFile failed. Trying audioread instead.
#   y_v1, sample_rate_v1 = librosa.load(vowel1)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)

# %%
## Applying fft to the signal
fft_vowel_a=np.fft.fft(time_series_vowel_a, n=None, axis=-1, norm=None)
print(fft_vowel_a)
# Out:
# [ 0.49951163+2.48412402e-15j -0.07087911-7.58735488e-02j
#  -0.05656783+7.17495536e-02j ...  0.06047789-9.35669311e-03j
#  -0.05656783-7.17495536e-02j -0.07087911+7.58735488e-02j]

# %%
amp_vowel_a=np.abs(fft_vowel_a)
plt.plot(amp_vowel_a)
plt.title('FFT Signal')
plt.show()

# %% [markdown]
# For vowel sound 2

# %%
vowel_i="vowel_i.m4a"
ipd.Audio(vowel_i)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mp4;base64,..." type="audio/mp4" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
time_series_vowel_i, sample_rate_vowel_i = librosa.load(vowel_i)
librosa.display.waveshow(time_series_vowel_i)
# Out:
# <ipython-input-34-0747e7271b21>:1: UserWarning: PySoundFile failed. Trying audioread instead.
#   y_v2, sample_rate_v2 = librosa.load(vowel_2)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)

# %%
## Applying fft to the signal
fft_vowel_i=np.fft.fft(time_series_vowel_i, n=None, axis=-1, norm=None)
print(fft_vowel_i)
# Out:
# [ 0.38835479+1.23512311e-15j -0.04425247-5.67796376e-02j
#  -0.03706156+3.90672151e-02j ...  0.00233366+4.60325360e-02j
#  -0.03706156-3.90672151e-02j -0.04425247+5.67796376e-02j]

# %%
amp_vowel_i=np.abs(fft_vowel_i)
plt.plot(amp_vowel_i)
plt.title('FFT Signal')
plt.show()

# %% [markdown]
# **A2.Repeat the A1 for a consonant sound. Perform the same for a few consonant sounds.**

# %%
consonant_h="consonant-h.m4a"
ipd.Audio(consonant_h)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mp4;base64,..." type="audio/mp4" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
time_signal_consonant_h, sample_rate_consonant_h = librosa.load(consonant_h)
librosa.display.waveshow(time_signal_consonant_h)
# Out:
# <ipython-input-38-dddbea1a61ab>:1: UserWarning: PySoundFile failed. Trying audioread instead.
#   time_signal_consonant_h, sample_rate_consonant_h = librosa.load(consonant_h)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)

# %%
## Applying fft to the signal
fft_consonant_h=np.fft.fft(time_signal_consonant_h, n=None, axis=-1, norm=None)
print(fft_consonant_h)
# Out:
# [0.19792105+1.33226763e-15j 0.10547467-4.31129706e-03j
#  0.1712393 +6.15430573e-02j ... 0.08909949-7.54740168e-03j
#  0.1712393 -6.15430573e-02j 0.10547467+4.31129706e-03j]

# %%
amplitude_consonant_h = np.abs(fft_consonant_h)
plt.plot(amplitude_consonant_h)
plt.title('FFT Signal of consonant h')
plt.show()

# %% [markdown]
# For 2nd consonant

# %%
consonant_r="consonant-r.m4a"
ipd.Audio(consonant_r)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mp4;base64,..." type="audio/mp4" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
time_signal_consonant_r, sample_rate_consonant_r = librosa.load(consonant_r)
librosa.display.waveshow(time_signal_consonant_r)
# Out:
# <ipython-input-42-0a2937b7206d>:1: UserWarning: PySoundFile failed. Trying audioread instead.
#   time_signal_consonant_r, sample_rate_consonant_r = librosa.load(consonant_r)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)

# %%
## Applying fft to the signal
fft_consonant_r=np.fft.fft(time_signal_consonant_r, n=None, axis=-1, norm=None)
print(fft_consonant_r)
# Out:
# [ 0.06251776+0.j         -0.02362399+0.04285766j  0.02034473-0.02578302j
#  ...  0.02536732-0.00322637j  0.02034473+0.02578302j
#  -0.02362399-0.04285766j]

# %%
amplitude_consonant_r=np.abs(fft_consonant_r)
plt.plot(amplitude_consonant_r)
plt.title('FFT Signal of consonat r')
plt.show()

# %% [markdown]
# **A3. Repeat A2 for few slices of silence & non-voiced portions of the recorded speech signal.**

# %%
silence="silence.m4a"
ipd.Audio(silence)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mp4;base64,..." type="audio/mp4" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
time_signal_silence, sample_rate_silence = librosa.load(silence)
librosa.display.waveshow(time_signal_silence)
# Out:
# <ipython-input-55-a681dfa2065e>:1: UserWarning: PySoundFile failed. Trying audioread instead.
#   time_signal_silence, sample_rate_silence = librosa.load(silence)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)

# %%
## Applying fft to the signal
fft_silence=np.fft.fft(time_signal_silence, n=None, axis=-1, norm=None)
print(fft_silence)
# Out:
# [0.00999556+0.j         0.00812298+0.00132856j 0.00756074+0.00286164j ...
#  0.00672079-0.00053603j 0.00756074-0.00286164j 0.00812298-0.00132856j]

# %%
amplitude_silence_signal=np.abs(fft_silence)
plt.plot(amplitude_silence_signal)
plt.title('FFT Signal of silence signal')
plt.show()

# %% [markdown]
# **For non-voice signal**

# %%
nonvoice='non-voice.m4a'
ipd.Audio(nonvoice)
time_signal_nonvoice, sample_rate_nonvoice = librosa.load(nonvoice)
librosa.display.waveshow(time_signal_nonvoice)

## Applying fft to the signal
fft_nonvoice=np.fft.fft(time_signal_nonvoice, n=None, axis=-1, norm=None)
print(fft_nonvoice)
amplitude_nonvoice_signal=np.abs(fft_nonvoice)
plt.plot(amplitude_nonvoice_signal)
plt.title('FFT Signal of non-voice signal')
plt.show()
# Out:
# <ipython-input-61-6d1c4b3c53de>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   time_signal_nonvoice, sample_rate_nonvoice = librosa.load(nonvoice)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [ 0.02620149+1.79717352e-15j  0.02705417+1.15760203e-02j
#   0.00586984-4.88386069e-02j ... -0.02933439-6.45734975e-02j
#   0.00586984+4.88386069e-02j  0.02705417-1.15760203e-02j]

# %% [markdown]
# **A4. Now you have acquainted yourself with spectral amplitudes of various consonants and vowel-basedphonemes. Generate the spectrogram of thesignal and observe the change points of the signals with associatedspeech segments. Observe to identify the consonants and vowels from the spectrogram.**

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display

signal = 'Audio.wav'
time_signal, sample_rate = librosa.load(signal)

# Compute the STFT
n_fft = 2048  # FFT window size
hop_length = 512  # Hop length for STFT
spectrogram = np.abs(librosa.stft(time_signal, n_fft=n_fft, hop_length=hop_length))

# Plot the spectrogram
plt.figure(figsize=(12, 6))
librosa.display.specshow(librosa.amplitude_to_db(spectrogram, ref=np.max), sr=sample_rate, hop_length=hop_length, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram of the signal')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.tight_layout()
plt.show()
